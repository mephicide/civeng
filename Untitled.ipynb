# %% [markdown]
# ## Enercalc
#
# - Concrete beam
# - Steel beam
# - Retaining Wall
# - etc.
#
# -- Does "Analysis" ... what are the loads and stresses in the element being nalyzed?
# -- "Shear", "moment" "axial" etc.
#
# -- "Design" takes the components resulting from analysis

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # What are the inputs?
#
# e.g. Beam:
# - Length

# %%
# !ls ~/Downloads/*.csv
# Out:
# /Users/jvickery/Downloads/Berlin_sample_feed.csv
# /Users/jvickery/Downloads/Geocoding_Sample_Mapfit.csv
# /Users/jvickery/Downloads/NY_NYC_sample_feed.csv
# /Users/jvickery/Downloads/SF_NYC_Restaurants.csv
# /Users/jvickery/Downloads/aisc-shapes-database-v15.0.csv

# %%
elastic_modulus = 29000 #ksi
steel_yield = 50 #ksi
aisc_csv = pd.read_csv('/Users/jvickery/Downloads/aisc-shapes-database-v15.0.csv')

# %%
pd.options.display.max_columns = None
aisc_csv.head()
# Out:
#   Type EDI_Std_Nomenclature AISC_Manual_Label T_F      W      A     d  \
# 0    W              W44X335           W44X335   F  335.0   98.5  44.0
# 1    W              W44X290           W44X290   F  290.0   85.4  43.6
# 2    W              W44X262           W44X262   F  262.0   77.2  43.3
# 3    W              W44X230           W44X230   F  230.0   67.8  42.9
# 4    W              W40X655           W40X655   T  655.0  193.0  43.6
#
#        ddet Ht  h OD    bf     bfdet  B  b ID     tw    twdet  twdet/2    tf  \
# 0  44        –  –  –  15.9  16        –  –  –   1.03  1           1/2   1.77
# 1  43  5/8   –  –  –  15.8  15  7/8   –  –  –  0.865     7/8      7/16  1.58
# 2  43  1/4   –  –  –  15.8  15  3/4   –  –  –  0.785    13/16     7/16  1.42
# 3  42  7/8   –  –  –  15.8  15  3/4   –  –  –  0.710    11/16     3/8   1.22
# 4  43  5/8   –  –  –  16.9  16  7/8   –  –  –   1.97  2        1        3.54
#
#      tfdet  t tnom tdes  kdes     kdet       k1  x  y eo xp yp bf/2tf b/t  \
# 0  1  3/4   –    –    –  2.56  3        1  3/4   –  –  –  –  –   4.50   –
# 1  1  9/16  –    –    –  2.36  2 13/16  1  5/8   –  –  –  –  –   5.02   –
# 2  1  7/16  –    –    –  2.20  2  5/8   1  5/8   –  –  –  –  –   5.57   –
# 3  1  1/4   –    –    –  2.01  2  7/16  1  9/16  –  –  –  –  –   6.45   –
# 4  3  9/16  –    –    –  4.72  4 13/16  2  3/16  –  –  –  –  –   2.39   –
#
#   b/tdes  h/tw h/tdes D/t       Ix      Zx      Sx    rx      Iy     Zy  \
# 0      –  38.0      –   –  31100.0  1620.0  1410.0  17.8  1200.0  236.0
# 1      –  45.0      –   –  27000.0  1410.0  1240.0  17.8  1040.0  205.0
# 2      –  49.6      –   –  24100.0  1270.0  1110.0  17.7   923.0  182.0
# 3      –  54.8      –   –  20800.0  1100.0   971.0  17.5   796.0  157.0
# 4      –  17.3      –   –  56500.0  3080.0  2590.0  17.1  2870.0  542.0
#
#       Sy    ry Iz rz Sz     J       Cw  C  Wno   Sw1 Sw2 Sw3   Qf    Qw ro  H  \
# 0  150.0  3.49  –  –  –  74.7   535000  –  168  1180   –   –  278   805  –  –
# 1  132.0  3.49  –  –  –  50.9   461000  –  166  1040   –   –  248   701  –  –
# 2  117.0  3.47  –  –  –  37.3   405000  –  165   928   –   –  223   630  –  –
# 3  101.0  3.43  –  –  –  24.9   346000  –  165   793   –   –  192   547  –  –
# 4  340.0  3.86  –  –  –   589  1150000  –  169  2530   –   –  529  1530  –  –
#
#   tan(α) Iw zA zB zC wA wB wC SwA SwB SwC SzA SzB SzC   rts    ho   PA PA2  \
# 0      –  –  –  –  –  –  –  –   –   –   –   –   –   –  4.24  42.2  132   –
# 1      –  –  –  –  –  –  –  –   –   –   –   –   –   –  4.20  42.0  131   –
# 2      –  –  –  –  –  –  –  –   –   –   –   –   –   –  4.17  41.9  131   –
# 3      –  –  –  –  –  –  –  –   –   –   –   –   –   –  4.13  41.7  130   –
# 4      –  –  –  –  –  –  –  –   –   –   –   –   –   –  4.71  40.1  132   –
#
#     PB   PC   PD         T      WGi WGo EDI_Std_Nomenclature.1  \
# 0  148  104  120  38        5  1/2    –              W1100X499
# 1  147  103  119  38        5  1/2    –              W1100X433
# 2  147  102  118  38        5  1/2    –              W1100X390
# 3  146  102  118  38        5  1/2    –              W1100X343
# 4  149  104  121  34        7  1/2    –              W1000X976
#
#   AISC_Manual_Label.1    W.1       A.1   d.1 ddet.1 Ht.1 h.1 OD.1 bf.1  \
# 0           W1100X499  499.0   63500.0  1120   1120    –   –    –  404
# 1           W1100X433  433.0   55100.0  1110   1110    –   –    –  401
# 2           W1100X390  390.0   49800.0  1100   1100    –   –    –  401
# 3           W1100X343  343.0   43700.0  1090   1090    –   –    –  401
# 4           W1000X976  975.0  125000.0  1110   1110    –   –    –  429
#
#   bfdet.1 B.1 b.1 ID.1  tw.1 twdet.1 twdet/2.1  tf.1 tfdet.1 t.1 tnom.1  \
# 0     406   –   –    –  26.2    25.4      12.7  45.0    44.4   –      –
# 1     403   –   –    –  22.0    22.2      11.1  40.1    39.7   –      –
# 2     400   –   –    –  19.9    20.6      11.1  36.1    36.5   –      –
# 3     400   –   –    –  18.0    17.5      9.52  31.0    31.8   –      –
# 4     429   –   –    –  50.0    50.8      25.4  89.9    90.5   –      –
#
#   tdes.1 kdes.1 kdet.1  k1.1 x.1 y.1 eo.1 xp.1 yp.1 bf/2tf.1 b/t.1 b/tdes.1  \
# 0      –   65.0   76.2  44.5   –   –    –    –    –     4.50     –        –
# 1      –   59.9   71.4  41.3   –   –    –    –    –     5.02     –        –
# 2      –   55.9   66.7  41.3   –   –    –    –    –     5.57     –        –
# 3      –   51.1   61.9  39.7   –   –    –    –    –     6.45     –        –
# 4      –    120    122  55.6   –   –    –    –    –     2.39     –        –
#
#   h/tw.1 h/tdes.1 D/t.1     Ix.1     Zx.1     Sx.1   rx.1    Iy.1    Zy.1  \
# 0   38.0        –     –  12900.0  26500.0  23100.0  452.0   499.0  3870.0
# 1   45.0        –     –  11200.0  23100.0  20300.0  452.0   433.0  3360.0
# 2   49.6        –     –  10000.0  20800.0  18200.0  450.0   384.0  2980.0
# 3   54.8        –     –   8660.0  18000.0  15900.0  445.0   331.0  2570.0
# 4   17.3        –     –  23500.0  50500.0  42500.0  434.0  1190.0  8880.0
#
#      Sy.1  ry.1 Iz.1 rz.1 Sz.1     J.1    Cw.1 C.1   Wno.1 Sw1.1 Sw2.1 Sw3.1  \
# 0  2460.0  88.6    –    –    –   31100  144000   –  108000   491     –     –
# 1  2160.0  88.6    –    –    –   21200  124000   –  107000   433     –     –
# 2  1920.0  88.1    –    –    –   15500  109000   –  106000   386     –     –
# 3  1660.0  87.1    –    –    –   10400   92900   –  106000   330     –     –
# 4  5570.0  98.0    –    –    –  245000  309000   –  109000  1050     –     –
#
#    Qf.1   Qw.1 ro.1 H.1 tan(α).1 Iw.1 zA.1 zB.1 zC.1 wA.1 wB.1 wC.1 SwA.1  \
# 0  4560  13200    –   –        –    –    –    –    –    –    –    –     –
# 1  4060  11500    –   –        –    –    –    –    –    –    –    –     –
# 2  3650  10300    –   –        –    –    –    –    –    –    –    –     –
# 3  3150   8960    –   –        –    –    –    –    –    –    –    –     –
# 4  8670  25100    –   –        –    –    –    –    –    –    –    –     –
#
#   SwB.1 SwC.1 SzA.1 SzB.1 SzC.1 rts.1  ho.1  PA.1 PA2.1  PB.1  PC.1  PD.1  \
# 0     –     –     –     –     –   108  1070  3350     –  3760  2640  3050
# 1     –     –     –     –     –   107  1070  3330     –  3730  2620  3020
# 2     –     –     –     –     –   106  1060  3330     –  3730  2590  3000
# 3     –     –     –     –     –   105  1060  3300     –  3710  2590  3000
# 4     –     –     –     –     –   120  1020  3350     –  3780  2640  3070
#
#    T.1 WGi.1 WGo.1
# 0  965   140     –
# 1  965   140     –
# 2  965   140     –
# 3  965   140     –
# 4  864   191     –

# %%
aisc_csv['EDI_Std_Nomenclature'].unique()
# Out:
# 2092

# %%
aisc_csv[aisc_csv['EDI_Std_Nomenclature']=='W12X14']['Zx']
# Out:
# 241    17.4
# Name: Zx, dtype: float64

# %%
# Code reference AISC Version 13 Equation (F2-1) on pg. 16.1-47
#Latex formatted Equation 
# Value in green or red depending on if it passes the "check"
def bendingCheck(yield_strength, shape_info, omega_factor=1.67):
    return ((yield_strength * shape_info['Zx']) / omega_factor) < 1

# %%
bendingCheck(50, aisc_csv[aisc_csv['EDI_Std_Nomenclature']=='W12X14'])
# Out:
# 241    False
# Name: Zx, dtype: bool

# %% [markdown]
# [bending check] for [12x14] [wide-flange] [A992] [steel beam]

# %%
elementTypes = ['STEEL', 'CONCRETE', 'MASONRY']

# %%
shapes = {
    'STEEL' : {
        'WIDE-FLANGE' : {
            '44x335': {
                
            }
        },
        'WT' : {
        
        },
        'CHANNEL' : {

        }
    }
}

# %%
beamDef = {
    'size': 10,
    'materialType' : 'STEEL',
    'materialSpec' : 'A992',
    'shape' : 'W12X14',
    'entityType' : 'BEAM'
}

# %%
def getProps(d):
    return aisc_csv[aisc_csv['EDI_Std_Nomenclature']==d['shape']]

# %%
getProps(beamDef)
# Out:
# 241    0.200
# Name: tw, dtype: object

# %%
def getShear(maxShear, shape_info):
    0.6 * shape_info['Aw']

# %%
codeChecks = [
    getShear,
    getYielding
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-9b02a87f8a99> in <module>
#       1 codeChecks = [
# ----> 2     getShear,
#       3     getYielding
#       4 ]
#       5
#
# NameError: name 'getShear' is not defined

# %%
dictionary = {
    'W225x123' : {
        'SubKey' : "Value"
    }
}

# %%
dictionary['W225x123']['SubKey']
# Out:
# 'Value'

# %%
d2 = {
 'whatTheF' : bendingCheck
}

# %%
d2['whatTheF'](50, aisc_csv[aisc_csv['EDI_Std_Nomenclature']=='W12X14'])
# Out:
# 241    False
# Name: Zx, dtype: bool
